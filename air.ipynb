# %%
#Importando bibliotecas necessárias

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Importando o dataset
df = pd.read_csv('airlines_flights_data.csv')
df.head(10).reset_index(drop=True)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5      5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6      6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7      7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8      8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9      9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# ...

# %% [markdown]
# Limpar dados

# %%
#limpeza de dados
df.isnull().sum()
# Out:
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Visualizando dados

# %%
#Tipos de dados
df.dtypes
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
# Descrição estatística dos dados
df.describe()
# Out:
#                index       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
#Destinos mais frequentes
print("\nQuantidades de cidades de destino:")
print(df['destination_city'].nunique())

plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='destination_city', order=df['destination_city'].value_counts().index)
sns.set(rc={'figure.figsize':(12, 6)})
sns.set_theme(style="whitegrid")
sns.set_palette("pastel")
plt.title('Destinos mais frequentes')
plt.xlabel('Número de voos')
plt.ylabel('Cidade de destino')
# Out:
# Quantidades de cidades de destino:
# 6
# Text(0, 0.5, 'Cidade de destino')

# %%
# Cidade de origem
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='source_city', order=df['source_city'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Cidades de origem dos voos')
plt.xlabel('Número de voos')
plt.ylabel('Cidade de origem')

#Quantidade de cidades
print("\nQuantidades de cidades de origem:")
print(df['source_city'].nunique())
# Out:
# Quantidades de cidades de origem:
# 6

# %%
#Analise de voos por companhia aérea
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='airline', order=df['airline'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Voos por companhia aérea')
plt.xlabel('Número de voos')
plt.ylabel('Companhia aérea')
# Out:
# Text(0, 0.5, 'Companhia aérea')

# %%
# Horas de partida
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='departure_time', order=df['departure_time'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Horas de partida dos voos')
plt.xlabel('Número de voos')
plt.ylabel('Hora de partida')

# Horas de chegada
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='arrival_time', order=df['arrival_time'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Horas de chegada dos voos')
plt.xlabel('Número de voos')
plt.ylabel('Hora de chegada')
# Out:
# Text(0, 0.5, 'Hora de chegada')

# %%
# Classe de voo
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='class', order=df['class'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Classes de voo')
plt.xlabel('Número de voos')
plt.ylabel('Classe de voo')
# Out:
# Text(0, 0.5, 'Classe de voo')

# %%
# Distribuição dos tempos de voo
plt.figure(figsize=(12, 6))
sns.histplot(df['duration'], bins=60, kde=True)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
plt.title('Distribuição dos tempos de voo')
plt.xlabel('Duração do voo (Horas)')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
# Dias Viajando
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='days_left', order=df['days_left'].value_counts().index)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
plt.title('Dias viajando')
plt.xlabel('Número de voos')
plt.ylabel('Dias viajando')
# Out:
# Text(0, 0.5, 'Dias viajando')

# %%
# Preço dos voos
plt.figure(figsize=(12, 6))
sns.histplot(df['price'], bins=60, kde=True)
sns.set_palette("pastel")
sns.set_theme(style="whitegrid")
plt.title('Distribuição dos preços dos voos')
plt.xlabel('Preço do voo (R$)')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
# Códigos de voo mais frequentes
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='flight', order=df['flight'].value_counts().index[:10])
sns.set_palette("Blues_r")
sns.set_theme(style="whitegrid")
plt.title('Códigos de voo mais frequentes')
plt.xlabel('Número de voos')
plt.ylabel('Código do voo')
plt.tight_layout()

# %% [markdown]
# Análises

# %%
# Análise de faturamento por companhia aérea
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='airline', y='price', estimator=np.sum, errorbar=None, palette='Blues_r', hue='airline')
sns.set_theme(style="whitegrid")
plt.title('Faturamento por companhia aérea')
plt.xlabel('Companhia aérea')
plt.ylabel('Faturamento (R$)')
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# A Empresa Vistara é claramente a companhia que mais faturou, seguido da empresa Air India.

# %%
#Analisando graficamente a classe de voo e o preço
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='class', y='price', palette='pastel',hue='class')
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(12, 6)})
plt.title('Análise de preço por classe de voo')
plt.xlabel('Classe de voo')
plt.ylabel('Preço do voo (R$)')
# Out:
# Text(0, 0.5, 'Preço do voo (R$)')

# %%
#Distribuição de preço por classe de cada companhia aérea
plt.figure(figsize=(12, 6))

companhias = df['airline'].unique()
for companhia in companhias:
    dados_companhia = df[df['airline'] == companhia]
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df[df['airline'] == companhia], x='class', y='price', palette='pastel', hue='class', showfliers=False)
    sns.set_theme(style="whitegrid")
    sns.set(rc={'figure.figsize':(12, 6)})
    companhia = companhia.replace('_', ' ').capitalize()
    plt.title(f'Distribuição de preço por classe de voo pela {companhia}')
    plt.xlabel('Classe de voo')
    plt.ylabel('Preço do voo (R$)')
    plt.legend(title=(companhia), bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
# Out:
# C:\Users\Cleis\AppData\Local\Temp\ipykernel_31680\2389088350.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title=(companhia), bbox_to_anchor=(1.05, 1), loc='upper left')
# C:\Users\Cleis\AppData\Local\Temp\ipykernel_31680\2389088350.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title=(companhia), bbox_to_anchor=(1.05, 1), loc='upper left')
# C:\Users\Cleis\AppData\Local\Temp\ipykernel_31680\2389088350.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title=(companhia), bbox_to_anchor=(1.05, 1), loc='upper left')
# ...

# %%
#Faturamento por companhia aérea
faturamento_por_companhia = df.groupby('airline')['price'].sum().reset_index()
#Organizar por faturamento
faturamento_por_companhia = faturamento_por_companhia.sort_values(by='price', ascending=False)

plt.figure(figsize=(8, 6))
sns.barplot(data=faturamento_por_companhia, x='airline', y='price',
             estimator=np.sum, errorbar=None, palette='Blues_r', hue='airline')
sns.set_theme(style="whitegrid")
sns.set_palette("Blues_r")
plt.title('Faturamento por companhia aérea')
plt.xlabel('Companhia aérea')
plt.ylabel('Faturamento (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

faturamento_por_companhia
# Out:
#      airline       price
# 5    Vistara  3886470735
# 1  Air_India  1901529790
# 3     Indigo   229580207
# 2   GO_FIRST   130973972
# 0    AirAsia    65858089
# 4   SpiceJet    55681482

# %% [markdown]
# Podemos ver que as empresas Vistara e Air India possuem os maiores faturamentos, justamente as empresas que também oferecem a classe executiva. É possível concluir que ambas as empresas são as maiores do setor.

# %%
#Distribuição de gastos por classe de voo 
for companhia in companhias:
    plt.figure(figsize=(15, 4))
    airline_data = df[df['airline'] == companhia]
    sns.histplot(airline_data['price'], bins=50, kde=True, color='green', 
                 label=companhia.replace('_', ' '), stat='count')
    sns.set_theme(style="darkgrid")
    sns.set_palette("colorblind")
    companhia = companhia.replace('_', ' ').capitalize()
    #média de gastos
    plt.axvline(airline_data['price'].quantile(0.10), color='#FFDAB9', linestyle='--', label=f'Q10: R$ {airline_data["price"].quantile(0.10):.2f}')
    plt.axvline(airline_data['price'].quantile(0.25), color='#F4A460', linestyle='--', label=f'Q1: R$ {airline_data["price"].quantile(0.25):.2f}')
    plt.axvline(airline_data['price'].mean(), color='blue', linestyle='--', label=f'Média: R$ {airline_data["price"].mean():.2f}')
    plt.axvline(airline_data['price'].median(), color='red', linestyle='--', label=f'Mediana: R$ {airline_data["price"].median():.2f}')
    plt.axvline(airline_data['price'].quantile(0.75), color='#FF8C00', linestyle='--', label=f'Q3: R$ {airline_data["price"].quantile(0.75):.2f}')
    plt.axvline(airline_data['price'].quantile(0.90), color='#D2691E', linestyle='--', label=f'Q90: R$ {airline_data["price"].quantile(0.90):.2f}')
    plt.title(f'Distribuição de gastos por classe de voo pela {companhia}')
    plt.xlabel('Preço do voo (R$)')
    plt.ylabel('Frequência')
    plt.legend(title=(companhia), bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Análise de atraso e cancelamento

# %% [markdown]
# Vamos ver as seguintes questões:

# %% [markdown]
# Qual companhia aérea mais atrasa?
# Quais rotas ou aeroportos têm mais cancelamentos?
# Em quais dias ou horários os atrasos são mais frequentes?

# %%
# Padronizar a coluna 'duration' para minutos
df['duration_minutes'] = (df['duration'].astype(float) * 60).round(2)
df['duration_minutes'].head(10)
# Out:
# 0    130.2
# 1    139.8
# 2    130.2
# 3    135.0
# 4    139.8
# 5    139.8
# 6    124.8
# 7    130.2
# 8    130.2
# 9    135.0
# Name: duration_minutes, dtype: float64

# %%
df.head(10).reset_index(drop=True)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5      5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6      6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7      7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8      8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9      9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price  duration_minutes
# ...

# %%
# Agrupar por rota e calcular a média de atrasos
df['route'] = df['source_city'] + ' - ' + df['destination_city']

media_desvio = df.groupby('route')['duration_minutes'].agg(['mean', 'std']).reset_index().round(2)
media_desvio_columns = ['route', 'mean_delay', 'std_delay']
df = df.merge(media_desvio, on='route', how='left')

df.head(10).reset_index(drop=True)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5      5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6      6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7      7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8      8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9      9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price  duration_minutes  \
# ...

# %%
# Verificar se o voo está atrasado
# Considerando um voo atrasado se a duração for maior que a média + desvio padrão
df['is_delayed'] = df['duration_minutes'] > df['mean'] + df['std']

df.head(10).reset_index(drop=True)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5      5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6      6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7      7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8      8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9      9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price  duration_minutes  \
# ...

# %%
# Atrasos por companhia aérea

atrasos_por_companhia = df.groupby('airline')['is_delayed'].mean().sort_values(ascending=False).reset_index()
atrasos_por_companhia.plot(kind='bar', x='airline', y='is_delayed', color='blue', legend=False,)
plt.title('Atrasos por Companhia Aérea')
plt.xlabel('Companhia Aérea')
plt.ylabel('Proporção de Atrasos')
plt.xticks(rotation=45)
plt.tight_layout()

atrasos_por_companhia
# Out:
#      airline  is_delayed
# 0  Air_India    0.312590
# 1   SpiceJet    0.288092
# 2    Vistara    0.196357
# 3    AirAsia    0.004535
# 4   GO_FIRST    0.000690
# 5     Indigo    0.000000

# %%
#Quantidade de atrasos por rota
atrasos_por_rota = df.groupby('route')['is_delayed'].mean().sort_values(ascending=False).reset_index()
atrasos_por_rota.plot(kind='bar', x='route', y='is_delayed', color='blue', legend=False)
plt.title('Atrasos por Rota')
plt.xlabel('Rota')
plt.ylabel('Proporção de Atrasos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
# Criar heatmap de atrasos por companhia aérea e rota
heatmap_data = df.pivot_table(index='airline', columns='route', values='is_delayed', aggfunc='mean')
plt.figure(figsize=(18, 8))
sns.heatmap(heatmap_data, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'label': 'Proporção de Atrasos'})
plt.title('Heatmap de Atrasos por Companhia Aérea e Rota')
plt.xlabel('Rota')
plt.ylabel('Companhia Aérea')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
# Correlação de faturamento e atrasos por empresa, ordenando por faturamento
faturamento_atrasos = df.groupby('airline').agg({'price': 'sum', 'is_delayed': 'mean'}).reset_index()
faturamento_atrasos = faturamento_atrasos.sort_values(by='price', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(data=faturamento_atrasos, x='airline', y='price', estimator=np.sum, errorbar=None, palette='Blues_r', hue='airline')
sns.set_theme(style="whitegrid")
plt.title('Correlação de Faturamento e Atrasos por Companhia Aérea')
plt.xlabel('Companhia Aérea')
plt.ylabel('Faturamento (R$)')
plt.xticks(rotation=45)
plt.tight_layout()
print('Como vimos anteriormente, as empresas Vistara e Air India possuem os maiores faturamentos, \njustamente as empresas que também oferecem a classe executiva. \n\nÉ possível concluir que ambas as empresas são as maiores do setor.')
print('')
print('--------------------------------------------------------------')
print('')
print('Já as menores empresas possuem menos problemas com atrasos, \ncomo a AirAsia e a IndiGo, que são conhecidas por serem low-cost e focadas em eficiência operacional. \n\nEssas empresas conseguem manter seus custos baixos e oferecer preços competitivos, \nmas podem ter menos recursos para lidar com atrasos e cancelamentos em comparação com as maiores companhias aéreas.')
# Out:
# Como vimos anteriormente, as empresas Vistara e Air India possuem os maiores faturamentos,
# justamente as empresas que também oferecem a classe executiva.
#
# É possível concluir que ambas as empresas são as maiores do setor.
#
# --------------------------------------------------------------
#
# Já as menores empresas possuem menos problemas com atrasos,
# como a AirAsia e a IndiGo, que são conhecidas por serem low-cost e focadas em eficiência operacional.
#
# Essas empresas conseguem manter seus custos baixos e oferecer preços competitivos,
# mas podem ter menos recursos para lidar com atrasos e cancelamentos em comparação com as maiores companhias aéreas.

# %%
#Rotas mais operadas
rotas_mais_operadas = df['route'].value_counts().head(10).reset_index()
rotas_mais_operadas.columns = ['route', 'count']
plt.figure(figsize=(12, 6))
sns.barplot(data=rotas_mais_operadas, x='route', y='count', palette='Blues_r',legend=False,hue='route')
plt.title('Rotas mais operadas')
plt.xlabel('Rota')
plt.ylabel('Número de voos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %%
# As rotas com mais concorrência
rotas_concorrencia = df['route'].value_counts().head(10).reset_index()
rotas_concorrencia.columns = ['route', 'count']
plt.figure(figsize=(12, 6))
sns.barplot(data=rotas_concorrencia, x='route', y='count', legend=False, hue='route', palette='Blues_r')
plt.title('Rotas com mais concorrência')
plt.xlabel('Rota')
plt.ylabel('Número de voos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# Qual a variação de tempo por companhia da mesma rota?

# %%
#Variação de tempo por companhia da mesma rota
variacao_tempo_rota = df.groupby(['airline', 'route'])['duration_minutes'].agg(['mean', 'std']).reset_index()
variacao_tempo_rota.columns = ['airline', 'route', 'mean_duration', 'std_duration']
plt.figure(figsize=(24, 12))
sns.barplot(data=variacao_tempo_rota, x='route', y='mean_duration', hue='airline', palette='viridis_r')
plt.title('Variação de tempo por companhia da mesma rota')
plt.xlabel('Rota')
plt.ylabel('Duração média do voo (minutos)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# Variação de preço de companhia por rota

# %%
#Variação de preço de companhia
variacao_preco_rota = df.groupby(['airline', 'route'])['price'].agg(['mean', 'std']).reset_index()
variacao_preco_rota.columns = ['airline', 'route', 'mean_price', 'std_price']
plt.figure(figsize=(24, 12))
sns.barplot(data=variacao_preco_rota, x='route', y='mean_price', hue='airline', palette='viridis_r')
plt.title('Variação de preço de companhia por rota')
plt.xlabel('Rota')
plt.ylabel('Preço médio do voo (R$)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# %% [markdown]
# Classificação de desempenho por rota

# %%
#Agrupando por companhia aérea
desempenho = df.groupby('airline').agg(
    total_voos=('airline', 'count'),
    total_atrasos=('is_delayed', 'sum'),
    preço_médio=('price', 'mean'),
    duração_média=('duration_minutes', 'mean')
).reset_index()

#Calculo de percentual de atrasos
desempenho['percentual_atrasos'] = (desempenho['total_atrasos'] / desempenho['total_voos']) * 100

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

#Normalizando os dados
desempenho_normalizado = desempenho[['percentual_atrasos', 'preço_médio', 'duração_média']].copy()
desempenho_normalizado = pd.DataFrame(scaler.fit_transform(desempenho_normalizado),
                                      columns=['atraso_normalizado', 'preco_normalizado', 'duracao_normalizada']
                                      , index=desempenho.index)


#Score final
desempenho_normalizado['score'] = (
    0.4 * desempenho_normalizado['atraso_normalizado'] +
    0.3 * desempenho_normalizado['preco_normalizado'] +
    0.3 * desempenho_normalizado['duracao_normalizada']
)

#Classificando
desempenho_normalizado['classificacao'] = pd.qcut(desempenho_normalizado['score'], q=5, labels=['E', 'D', 'C', 'B', 'A'])

#Jutando com os dados originais
desempenho_final = desempenho.join(desempenho_normalizado)

#Exibindo o resultado
print("\nClassificação de desempenho por companhia aérea:")
print("")
print(desempenho_final.sort_values('classificacao').reset_index(drop=True))
# Out:
# Classificação de desempenho por companhia aérea:
#
#      airline  total_voos  total_atrasos   preço_médio  duração_média  \
# 0    AirAsia       16098             73   4091.072742     536.502870
# 1     Indigo       43120              0   5324.216303     347.711800
# 2   GO_FIRST       23173             16   5652.007595     525.322798
# 3   SpiceJet        9011           2596   6179.278881     754.786017
# 4    Vistara      127859          25106  30396.536302     799.598070
# 5  Air_India       80892          25286  23507.019112     930.254117
#
#    percentual_atrasos  atraso_normalizado  preco_normalizado  \
# 0            0.453472            0.014507           0.000000
# 1            0.000000            0.000000           0.046878
# 2            0.069046            0.002209           0.059339
# 3           28.809233            0.921631           0.079383
# 4           19.635692            0.628162           1.000000
# 5           31.258963            1.000000           0.738096
# ...

# %%
#Heatmap de desempenho
plt.figure(figsize=(12, 8))
sns.heatmap(desempenho_final[['total_voos', 'total_atrasos', 'preço_médio', 'duração_média', 'percentual_atrasos']].corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap de Desempenho por Companhia Aérea')
plt.xlabel('Variáveis')
plt.ylabel('Variáveis')
plt.tight_layout()
plt.show()

# %% [markdown]
# Veremos quais rotas cada empresa possue o melhor desempenho

# %%
# Melhores rotas por companhia aérea
melhores_rotas_por_companhia = (
    desempenho_final.groupby(['airline', 'route'], as_index=False)
    .agg(
        media_score=('score', 'mean'),
        classificacao_mais_comum=('classificacao', lambda x: x.mode()[0]),
        total_voos=('airline', 'count')
    )
    .sort_values(by='media_score', ascending=False)
    .groupby('airline')
    .first()
    .reset_index()
)

#Exibindo resultados
melhores_rotas_por_companhia[['airline', 'route', 'media_score', 'classificacao_mais_comum', 'total_voos']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[275], line 3
#       1 # Melhores rotas por companhia aérea
#       2 melhores_rotas_por_companhia = (
# ----> 3     desempenho_final.groupby(['airline', 'route'], as_index=False)
#       4     .agg(
#       5         media_score=('score', 'mean'),
#       6         classificacao_mais_comum=('classificacao', lambda x: x.mode()[0]),
#       7         total_voos=('airline', 'count')
#       8     )
#       9     .sort_values(by='media_score', ascending=False)
#      10     .groupby('airline')
#      11     .first()
#      12     .reset_index()
#      13 )
#      15 #Exibindo resultados
#      16 melhores_rotas_por_companhia[['airline', 'route', 'media_score', 'classificacao_mais_comum', 'total_voos']]
#
# ...

# %% [markdown]
# Modelo de previsão de atraso

# %%
# Modelo de previsão com regressão logística
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

#Selecionando colunas relevantes
colunas_relevantes = ['airline', 'source_city', 'destination_city', 'departure_time', 'arrival_time', 'class', 'days_left', 'price', 'duration_minutes', 'route', 'mean', 'std','stops']

target = 'is_delayed'

x = df[colunas_relevantes]
y = df[target].astype(int) # Convertendo booleano para int

#Definindo colunas numéricas e categóricas
categorical_cols = ['airline', 'source_city', 'destination_city', 'departure_time', 'stops', 'class', 'route']
numerical_cols = ['days_left', 'price', 'duration_minutes', 'mean', 'std']

#Preprocessamento
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

#Pipeline
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

#Dividindo em treino e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#Treinando o modelo
pipeline.fit(x_train, y_train)

#Fazendo previsões
y_pred = pipeline.predict(x_test)

#Avaliação do modelo
print("Matrix de Confusão:")
print(confusion_matrix(y_test, y_pred))
print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred))

#Acurácia do modelo
accuracy = pipeline.score(x_test, y_test)
print(f"\nAcurácia do modelo: {accuracy:.2f}")
# Out:
# Matrix de Confusão:
# [[49416    24]
#  [   15 10576]]
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     49440
#            1       1.00      1.00      1.00     10591
#
#     accuracy                           1.00     60031
#    macro avg       1.00      1.00      1.00     60031
# weighted avg       1.00      1.00      1.00     60031
#
#
# Acurácia do modelo: 1.00

# %%
#Visualizando as previsões graficamente

plt.figure(figsize=(12, 6))
ax = sns.countplot(x=y_test, hue=y_pred, palette='pastel',legend=False,stat='probability')
for p in ax.patches:
    value = p.get_height() * 100
    ax.annotate(f'{value:.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', fontsize=12, color='black')   
plt.title('Comparação entre Valores Reais e Previsões de Atrasos')
plt.xlabel('Valores Reais')
plt.ylabel('Previsões de Atrasos')
plt.xticks([0, 1], ['Não Atrasado', 'Atrasado'])
plt.legend(title='Previsões', loc='upper right', labels=['Não Atrasado', 'Atrasado'])
plt.tight_layout()

# %%
#Verificando o Overfitting

from sklearn.metrics import classification_report

#Previsões de treino 
y_pred_train = pipeline.predict(x_train)
print("Teste:")
print(classification_report(y_train,y_pred_train))

#Previsões no teste
y_pred_test = pipeline.predict(x_test)
print("Teste:")
print(classification_report(y_test,y_pred_test))
# Out:
# Teste:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    197636
#            1       1.00      1.00      1.00     42486
#
#     accuracy                           1.00    240122
#    macro avg       1.00      1.00      1.00    240122
# weighted avg       1.00      1.00      1.00    240122
#
# Teste:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     49440
#            1       1.00      1.00      1.00     10591
#
#     accuracy                           1.00     60031
#    macro avg       1.00      1.00      1.00     60031
# weighted avg       1.00      1.00      1.00     60031

# %%
#Cross validation

from sklearn.model_selection import cross_val_score

scores = cross_val_score(pipeline, x, y, cv=5,scoring='accuracy')
print("Acurácia:",scores)
print("Média:",np.mean(scores))

print("\n\n As médias não variaram muito, mostrando que o modelo possui uma boa generalização.")
# Out:
# Acurácia: [0.99791774 0.99693492 0.99783445 0.99758454 0.99905047]
# Média: 0.9978644254968794
#
#
#  As médias não variaram muito, mostrando que o modelo possui uma boa generalização.

# %%
#Curva de aprendizado
from sklearn.model_selection import learning_curve

train_size, train_scores, test_scores = learning_curve(pipeline, x, y, cv=5, scoring="accuracy")

plt.plot(train_size, np.mean(train_scores, axis=1), label = "Treino")
plt.plot(train_size, np.mean(test_scores, axis=1), label = "Teste")
plt.xlabel("Tamanho do conjunto de treino")
plt.ylabel("Acurácua")
plt.legend()

# %% [markdown]
# Após toda a análise, utilizando o modelo de regressão linear, é possível concluir que os dados são suficientes para criar modelos de previsão com alta taxa de acurácidade. O desempenho quase perfeito mostra que há possibilidade de generalizar bem os dados mesmo quando ainda não vistos. O modelo capta padrões genuínos e não apenas informações diretas sobre atraso.
